# %% [markdown]
# ## use random # generator to simulate a simple gaussian process

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# set some properties of the random system

# %%
n_samples = 10000 ##of random samples to use
n_bins = 100  ##of bins for our histogram
sigma = 1.0  #rms width of the gaussian
mu = 0.0   #mean of gaussian

# %% [markdown]
# generate random # using numpy

# %%
x = np.random.normal(mu,sigma,n_samples)
print(x.min())
print(x.max())
# Out:
# -4.090921216906619
# 3.6302408116176004

# %% [markdown]
# ## define function to plot gaussian

# %%
def gaussian(x,mu,sigma):
    return 1./(2.0*np.pi*sigma**2)**0.5 * np.exp(-0.5*((x-mu)/sigma)**2)

# %% [markdown]
# ## create histogram of data

# %%
fig = plt.figure(figsize=(7,7))
y_hist, x_hist, ignored = plt.hist(x, bins=n_bins, range=[-5,5], density=True)
xx = np.linspace(-5.0,5.0,1000)
plt.plot(xx,gaussian(xx,mu,sigma),color="red")
plt.ylim([0,0.5])
plt.xlim([-5,5])
plt.gca().set_aspect(20)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show()
